# %% [markdown]
# # April 19th
#
# ## OECD Investment Matrix

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import json
from IPython.display import Image

# %% [markdown]
# $$O_{44x44}=(R_{44x41}V_{41x41}C_{41x44}\quad\emptyset\quad j_{44}R_{44x41}V_{41x41}C_{41x44})$$
#
# Where R sums and splits columns such that rows are split according to the relative weight of total production (e.g. if Agriculture is being split into Farming, which produces 80% and Fishing, which produces 20% of capital). C averages and splits columns such that the averages are weighted according to their total expenditure. We have expenditure weightings of VomLehn-Winberry industries but would need production weightings of OECD industries (some of which we could direcelty map from BEA).
#
# Currently R assumes uniform production when splitting industry rows.

# %%
res = pd.read_csv("investment_matrix.csv", index_col=0)

fig = px.imshow(res)
fig.update_layout(
    autosize=False,
    width=800,
    height=800
)

#fig.show()
Image("oecd_invmat.png")

# %% [markdown]
# ## Email to OECD for NAICS to OECD cross walk
#
# Subject: ICIO Cross Walks
#
# Dear ICIO team,
#
# I hope this email finds you well. I'm Francois Lafond, Deputy Director at the Institute of New Economic Thinking at the Oxford Martin School. Thank you for putting together the international IOT data, we've found it very helpful for our research.
#
# We're interested in constructing an inter-industry investment network following the format of the ICIO and are currently working with data from the United States. Knowing the US is in the ICIO tables, we'd be interested in any cross-walks betweeen NAICS industries and ISIC 4 industries that you've put together. We'd like to stay consistent.
#
# Would you be able to share any cross-walks of this sort that you have?
#
# Thank you,
#
# Francois Lafond

# %% [markdown]
# ## Eurostat ESA assets to NACE Industries
#
# ESA Asset Codes: https://ec.europa.eu/eurostat/esa2010/chapter/view/23/
#
# This may be more of an art than a science. I'm unable to find a direct crosswalk but I can produce a similar subjective mapping that we can discuss for next time.
